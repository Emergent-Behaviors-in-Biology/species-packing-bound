# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-library" data-toc-modified-id="Load-library-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load library</a></span></li><li><span><a href="#Dynamics" data-toc-modified-id="Dynamics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dynamics</a></span></li><li><span><a href="#Distributions" data-toc-modified-id="Distributions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Distributions</a></span><ul class="toc-item"><li><span><a href="#Resource-abundance" data-toc-modified-id="Resource-abundance-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Resource abundance</a></span></li><li><span><a href="#Species-Abundance" data-toc-modified-id="Species-Abundance-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Species Abundance</a></span></li><li><span><a href="#Dominator" data-toc-modified-id="Dominator-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Dominator</a></span></li></ul></li><li><span><a href="#Cavity" data-toc-modified-id="Cavity-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cavity</a></span></li><li><span><a href="#Large-Range" data-toc-modified-id="Large-Range-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Large Range</a></span><ul class="toc-item"><li><span><a href="#Common-Properties" data-toc-modified-id="Common-Properties-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Common Properties</a></span></li><li><span><a href="#Suspecities" data-toc-modified-id="Suspecities-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Suspecities</a></span></li><li><span><a href="#Cavity-Approximations:-Resources" data-toc-modified-id="Cavity-Approximations:-Resources-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Cavity Approximations: Resources</a></span></li><li><span><a href="#Cavity-Approximations:-Species" data-toc-modified-id="Cavity-Approximations:-Species-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Cavity Approximations: Species</a></span></li><li><span><a href="#Cavity-Approximations:-Consumer-power" data-toc-modified-id="Cavity-Approximations:-Consumer-power-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Cavity Approximations: Consumer power</a></span><ul class="toc-item"><li><span><a href="#Simulations" data-toc-modified-id="Simulations-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Simulations</a></span></li><li><span><a href="#Cavity-solutions" data-toc-modified-id="Cavity-solutions-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Cavity solutions</a></span></li></ul></li><li><span><a href="#Cavity-Approximations:-Growth-Rates" data-toc-modified-id="Cavity-Approximations:-Growth-Rates-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Cavity Approximations: Growth Rates</a></span><ul class="toc-item"><li><span><a href="#Linear" data-toc-modified-id="Linear-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Linear</a></span></li><li><span><a href="#Quadratic" data-toc-modified-id="Quadratic-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Quadratic</a></span></li></ul></li><li><span><a href="#Cavity-Approximations:-Suspecties" data-toc-modified-id="Cavity-Approximations:-Suspecties-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Cavity Approximations: Suspecties</a></span></li><li><span><a href="#Cavity-Approximations:-Dominator" data-toc-modified-id="Cavity-Approximations:-Dominator-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Cavity Approximations: Dominator</a></span></li></ul></li><li><span><a href="#Species-Packing-Bounds" data-toc-modified-id="Species-Packing-Bounds-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Species Packing Bounds</a></span><ul class="toc-item"><li><span><a href="#Quadratic" data-toc-modified-id="Quadratic-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Quadratic</a></span></li><li><span><a href="#Linear" data-toc-modified-id="Linear-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Linear</a></span></li></ul></li><li><span><a href="#Test-suspecities-calculations" data-toc-modified-id="Test-suspecities-calculations-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Test suspecities calculations</a></span><ul class="toc-item"><li><span><a href="#From-Inverse-of-Whole-Matrix" data-toc-modified-id="From-Inverse-of-Whole-Matrix-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>From Inverse of Whole Matrix</a></span></li><li><span><a href="#From-Inversie-of-Block-Matrix" data-toc-modified-id="From-Inversie-of-Block-Matrix-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>From Inversie of Block Matrix</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Load library

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
import pandas as pd
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib
from matplotlib import cm
from matplotlib import colors
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from Eco_function.eco_plot import *
import pickle
import matplotlib.gridspec as gridspec
tableau20=color20() # initial colors for plot;
sns.set(style="white")
from scipy.integrate import quad,quadrature
from scipy.stats import truncnorm
from scipy.stats import norm
fontsize=16
def integrmomentum1(x, a):
    return 1/np.sqrt(2*np.pi)*np.exp(-x**2/2)*(x+a)
def integrmomentum2(x, a):
    return 1/np.sqrt(2*np.pi)*np.exp(-x**2/2)*(x+a)**2

# %%
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
df1=pd.read_csv(file_name)
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_4.csv'
df2=pd.read_csv(file_name)
frames = [df1, df2]
result = pd.concat(frames)
result.to_csv('Data/Community_gaussian_null_linear_CVXOPT_log_sigc_3.csv',index=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %% [markdown]
# ## Dynamics

# %%
f, ax1 = plt.subplots()
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
fontsize=20
def fun(gamma,R):
    return R**gamma/(R**gamma+1.0)
R=np.linspace(0,1,1000)

ax1.plot(R,R*(1-R), label= 'Self-Renewing',c=tableau20[4])
ax1.plot(R,(1-R), label= 'Externallly Supplied',c=tableau20[0],linestyle='dashed')

#plt.plot(R, 1.0*np.ones(len(R)), label= 'constant',c=tableau20[4])
ax1.set_xlabel(r'$\displaystyle R_\alpha$',fontsize=fontsize)    
ax1.set_ylabel(r'$\displaystyle h_\alpha(R_\alpha)$',fontsize=fontsize) 
ax1.set_xlim(left=0)
ax1.set_xlim(right=1.0)
ax1.set_ylim(bottom=0)
ax1.set_ylim(top=1.1)
ax1.legend(fontsize=12)
f.set_size_inches(4, 3)
f.savefig('Supply.pdf', dpi=300, bbox_inches='tight',transparent=True)

# %% [markdown]
# ## Distributions
# ### Resource abundance

# %%
import pickle
with open('Data/abundance_qu.pkl','rb') as f:  
    Ns, Rs, Gs, epsilon, mu, K = pickle.load(f)
f, ax = plt.subplots()
num_bins=200
n, bins, patches = ax.hist(Rs, num_bins, normed=1, facecolor='blue', alpha=0.5,label='Simulation')

sigma=round(np.std(Rs),2)
mu=round(np.mean(Rs),2)
y = ((1 /(np.sqrt(2 * np.pi) * sigma))*np.exp(-0.5 *(1 /sigma * (bins - mu))**2))
ax.plot(bins, y, 'b',linestyle='dashed',label='Curve Fitting: $\mu=$'+str(mu)+', $\sigma=$'+str(sigma))

ax.set_xlabel('Resources Abundance',fontsize=20)
ax.set_ylabel('Probability density',fontsize=20)
ax.set_title(r'Self-Renewing',fontsize=20)
ax.set_ylim((0,1.8))
ax.set_xlim((0,2.1))
ax.legend(fontsize=15)
fig_name='Resources_qu.pdf'
ax.tick_params(axis='both', which='major', labelsize=22)
f.set_size_inches(7, 5)
f.savefig(fig_name, dpi=100,bbox_inches='tight',transparent='True')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
import pickle
with open('Data/abundanceK_5.0Sigc_20w_1.0ODE.pkl','rb') as f: 
    Ns, Rs, Gs, Ds, epsilon, mu, K = pickle.load(f)
f, ax = plt.subplots()
num_bins=100
n, bins, patches = ax.hist(Rs, num_bins, normed=1, facecolor='blue', alpha=0.5,label='Simulation')

sigma=round(np.std(Rs),2)
mu=round(np.mean(Rs),2)
y = ((1 /(np.sqrt(2 * np.pi) * sigma))*np.exp(-0.5 *(1 /sigma * (bins - mu))**2))
ax.plot(bins, y, 'b',linestyle='dashed',label='Curve Fitting: $\mu=$'+str(mu)+', $\sigma=$'+str(sigma))

ax.set_xlabel('Resources Abundance',fontsize=20)
ax.set_ylabel('Probability density',fontsize=20)
ax.set_title(r'Externallly Supplied',fontsize=20)
ax.set_ylim((0,1.2))
ax.set_xlim((0,25.5))
ax.legend(fontsize=15)
fig_name='Resources_li.pdf'
ax.tick_params(axis='both', which='major', labelsize=22)
f.set_size_inches(7, 5)
f.savefig(fig_name, dpi=100,bbox_inches='tight',transparent='True')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
np.min(Rs)
# Out:
# 0.021732832425893266

# %%
with open('Data/abundanceK_1.0Sigc_20w_1.0ODE.pkl','rb') as f: 
    Ns, Rs, Gs, Ds, epsilon, mu, K = pickle.load(f)
print('resource', np.max(Rs))
print('dominator', np.min(Ds))
print('dominator', np.max(1/np.asarray(Ds)))
print('mean', np.mean(Rs))
print('var', np.var(Rs))
with open('Data/abundanceK_1.0Sigc_20w_1.0.pkl','rb') as f: 
    Ns, Rs, Gs, Ds, epsilon, mu, K = pickle.load(f)
print('mean', np.mean(Rs))
print('var', np.var(Rs))
# Out:
# resource 7.20039642760178
# dominator 0.13524541141133084
# dominator 7.393966194968594
# mean 0.4435095901498938
# var 0.4212149684263678
# mean 0.3968662416784702
# var 0.18398100244230628

# %% [markdown]
# ### Species Abundance

# %%
with open('Data/abundanceK_5.0Sigc_20w_1.0.pkl','rb') as f: 
    Ns, Rs, Gs, Ds, epsilon, mu, K = pickle.load(f)
f, ax = plt.subplots()
num_bins=100
data=np.asarray(Ns)
n, bins, patches = ax.hist(data, num_bins, normed=1, facecolor='blue', alpha=0.5,label='Simulation')

sigma=round(np.std(data),2)
mu=round(np.mean(data),2)
y = ((1 /(np.sqrt(2 * np.pi) * sigma))*np.exp(-0.5 *(1 /sigma * (bins - mu))**2))
ax.plot(bins, y, 'b',linestyle='dashed',label='Curve Fitting: $\mu=$'+str(mu)+', $\sigma=$'+str(sigma))

ax.set_xlabel('Species Abundance',fontsize=20)
ax.set_ylabel('Probability density',fontsize=20)
ax.set_title(r'Externallly Supplied',fontsize=20)
ax.set_ylim((0,5))
ax.set_xlim((0,10))
ax.legend(fontsize=15)
fig_name='Species_li.pdf'
ax.tick_params(axis='both', which='major', labelsize=22)
f.set_size_inches(7, 5)
f.savefig(fig_name, dpi=100,bbox_inches='tight',transparent='True')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
np.max(Ns)
# Out:
# 22.880815329754395

# %% [markdown]
# ### Dominator

# %%
with open('Data/abundanceK_5.0Sigc_20w_1.0ODE.pkl','rb') as f:  
    Ns, Rs, Gs, Ds, epsilon, mu, K = pickle.load(f)
f, ax = plt.subplots()
num_bins=200
data=np.asarray(Ds)
n, bins, patches = ax.hist(data,np.linspace(-1,200,num_bins), normed=1, facecolor='blue', alpha=0.5,label='Simulation')

sigma=round(np.std(data),2)
mu=round(np.mean(data),2)
y = ((1 /(np.sqrt(2 * np.pi) * sigma))*np.exp(-0.5 *(1 /sigma * (bins - mu))**2))
ax.plot(bins, y, 'b',linestyle='dashed',label='Curve Fitting: $\mu=$'+str(mu)+', $\sigma=$'+str(sigma))

ax.set_xlabel('Dominator of Resources Abundance',fontsize=20)
ax.set_ylabel('Probability density',fontsize=20)
ax.set_title(r'Externallly Supplied',fontsize=20)
#ax.set_ylim((0,3.2))
#ax.set_xlim((0,1.5))
ax.legend(fontsize=15)
fig_name='Rdominator_li.pdf'
ax.tick_params(axis='both', which='major', labelsize=22)
f.set_size_inches(7, 5)
f.savefig(fig_name, dpi=100,bbox_inches='tight',transparent='True')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ## Cavity

# %%
k=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
#file_name='Data/Community_gaussian_null_linear_ODE_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]

file_name='Data/Cavity_linear.csv'
data1=pd.read_csv(file_name)
data1=data1[data1['K']==k]

file_name='Data/Cavity_linear_1st.csv'
data2=pd.read_csv(file_name)
data2=data2[data2['K']==k]

fig = plt.figure(figsize=(10, 8))
gs = gridspec.GridSpec(nrows=6, ncols=2)
fontsize=25
ax11 = fig.add_subplot(gs[:2, 0])
ax21 = fig.add_subplot(gs[2:4, 0])
ax31 = fig.add_subplot(gs[4:, 0])
ax12 = fig.add_subplot(gs[:3, 1])
ax22 = fig.add_subplot(gs[3:, 1])
axs=[ax11 ,ax21,ax31,ax12, ax22]
Y1=['phi_N', 'mean_N', 'mean_R', 'q_N', 'q_R']
Y2=['phiN', 'N', 'R', 'qN', 'qR']
Labels=[r'$\phi_N$', '$<N>$', '$<R>$',r'$<N^2>$',r'$<R^2>$']
for i in range(5):
    ax=axs[i]
   #ax.tick_params(axis='both', which='major', labelsize=12)
    ax.plot(data0['epsilon'], data0[Y1[i]],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0])
    ax.plot(data1['Sigc'], data1[Y2[i]],linestyle='-',label='Cavity: $0^{th}$',linewidth=3,c=tableau20[6])
    ax.plot(data2['Sigc'], data2[Y2[i]],linestyle='-.',label='Cavity: $1^{st}$',linewidth=3,c=tableau20[6])
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.1,2.1)
    if i==1: ax.set_ylim(0.,1)
    if i==2: ax.set_ylim(0.,2)
    if i==4: ax.set_ylim(0.,1.5)
    if i==3:
        ax.set_ylim(0.,10)
        ax.legend(fontsize=20,loc='upper right')
fig.tight_layout()
fig_name='Cavity_simulations.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %%
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
k=1
gamma=1
mu=1
data0=data0[data0['K']==k]
data0=data0[data0['epsilon']==0.5]
print(data0[['epsilon','phi_N','mean_N', 'q_N', 'nu','chi','mean_R', 'q_R']])
Chi=-gamma/(2*data0['nu']*data0['epsilon']**2)*(1-\
(gamma+mu*data0['mean_N'])/np.sqrt((gamma+mu*data0['mean_N'])**2-4*data0['nu']*gamma*k*data0['epsilon']**2)\
+(1+mu*data0['mean_N']/gamma)*(data0['epsilon']**2*data0['q_N'])/2/((1+mu*data0['mean_N'])**2/gamma-4*data0['nu']/gamma*k*data0['epsilon']**2)**(3/2))
print('chi cavity',Chi, 'simulation',data0['chi'])
nu=-data0['phi_N']/(data0['epsilon']**2*Chi)
print('nu cavity',nu, 'simulation',data0['nu'])
# Out:
#     epsilon     phi_N    mean_N       q_N        nu       chi    mean_R  \
# 10      0.5  0.175105  0.360286  1.286486 -1.878518  0.365916  0.658107
#
#          q_R
# 10  0.484267
# chi cavity 10    0.347024
# dtype: float64 simulation 10    0.365916
# Name: chi, dtype: float64
# nu cavity 10   -2.018362
# dtype: float64 simulation 10   -1.878518
# Name: nu, dtype: float64

# %% [markdown]
# ## Large Range
# ### Common Properties

# %%
k=10.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]

file_name='Data/Cavity_linear.csv'
data1=pd.read_csv(file_name)
data1=data1[data1['K']==k]

file_name='Data/Cavity_linear_1st.csv'
data2=pd.read_csv(file_name)
data2=data2[data2['K']==k]

fig = plt.figure(figsize=(10, 8))
gs = gridspec.GridSpec(nrows=6, ncols=2)
fontsize=25
ax11 = fig.add_subplot(gs[:2, 0])
ax21 = fig.add_subplot(gs[2:4, 0])
ax31 = fig.add_subplot(gs[4:, 0])
ax12 = fig.add_subplot(gs[:3, 1])
ax22 = fig.add_subplot(gs[3:, 1])
axs=[ax11 ,ax21,ax31,ax12, ax22]
Y1=['phi_N', 'mean_N', 'mean_R', 'q_N', 'q_R']
Y2=['phiN', 'N', 'R', 'qN', 'qR']
Labels=[r'$\phi_N$', '$<N>$', '$<R>$',r'$<N^2>$',r'$<R^2>$']
for i in range(5):
    ax=axs[i]
    ax.tick_params(axis='both', which='major', labelsize=12)
    #ax.plot(data0['epsilon'], data0[Y1[i]],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0])
    ax.plot(data0['epsilon'], data0[Y1[i]],label='Simulations_CVXOPT',linestyle='--',linewidth=3,c=tableau20[0])
    ax.plot(data1['Sigc'], data1[Y2[i]],linestyle='-',label='Cavity: $0^{th}$',linewidth=3,c=tableau20[6])
    ax.plot(data2['Sigc'], data2[Y2[i]],linestyle='-.',label='Cavity: $1^{st}$',linewidth=3,c=tableau20[6])
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.1,20.1)
    if i==0: 
        ax.set_ylim(0.,0.6)
        ax.axhline(y=0.5, linewidth=3, color='k', linestyle='dashed')
    #if i==1: ax.set_ylim(0.,2)
    if i==3:
        ax.set_ylim(0.,1000)
        ax.legend(fontsize=20,loc='upper right')
fig.tight_layout()
fig_name='Cavity_simulations_1.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')
plt.show()

# %% [markdown]
# ### Suspecities

# %%
k=1.
gamma=1
mu=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
f, (ax1, ax2) = plt.subplots(1, 2,figsize=(13,5))
fontsize=16
ax1.tick_params(axis='both', which='major', labelsize=12)
ax1.plot(data0['epsilon'], data0['chi'],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0])
#ax1.plot(data0['epsilon'], data0['q_R']/k,linestyle='-',label='Cavity: $0^{th}$',linewidth=3,c=tableau20[6])
ax1.plot(data0['epsilon'], gamma*k/(1+1/gamma*mu*data0['mean_N'])**2-3/2*gamma*k*data0['phi_N']/(1+mu*data0['mean_N']/gamma)**2,linestyle='-.',label='Cavity: $1^{st}$',linewidth=3,c=tableau20[6])
ax1.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
ax1.set_ylabel(r'$\chi$',fontsize=16)
ax1.legend(fontsize=15,loc='upper right')
ax1.set_xlim(0.01,2.)
#ax1.set_ylim(-0.6,1.7)

ax2.plot(data0['epsilon'], data0['nu'],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0])
#ax2.plot(data0['epsilon'], -data0['phi_N']*(1+mu*data0['mean_N']/gamma)**2/(data0['epsilon']**2*k),linestyle='-.',label='Cavity: $1^{st}$',linewidth=3,c=tableau20[6])
ax2.tick_params(axis='both', which='major', labelsize=12)
ax2.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
ax2.set_ylabel(r'$\nu$',fontsize=16)
ax1.set_xlim(-0.01,2.)
fig.tight_layout()
fig_name='Suspecities.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Resources

# %%
k=1.
gamma=1
mu=1.
sigk=0.1
fontsize=15
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['mean_R'], data0['q_R']]
Y0=[k/(1+1/gamma*mu*data0['mean_N']), data0['q_R']+data0['q_R']/k**2*sigk**2+data0['epsilon']**2/gamma*data0['mean_R']**4/k**2*data0['q_N']]

y1=(1+mu*data0['mean_N']/gamma)/(2*data0['epsilon']**2*data0['nu']/gamma)\
-np.sqrt((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2)/(2*data0['epsilon']**2*data0['nu']/gamma)\
-(data0['epsilon']**2*data0['q_N'])/(4*data0['epsilon']**2*data0['nu']/gamma*np.sqrt((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2))
y2=data0['mean_R']**2\
+2*(data0['epsilon']**2*data0['q_N'])*(np.sqrt((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2)-(1+mu*data0['mean_N']/gamma))**2\
/(2*((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2))/(2*data0['epsilon']**2*data0['nu']/gamma)**2\
+(data0['epsilon']**2*data0['q_N'])**2/(2*((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2))/(2*data0['epsilon']**2*data0['nu']/gamma)**2\
+8*(data0['nu']/gamma*sigk*data0['epsilon']**2)**2/(2*((1+mu*data0['mean_N']/gamma)**2-4*data0['nu']/gamma*k*data0['epsilon']**2))/(2*data0['epsilon']**2*data0['nu']/gamma)**2
Labels=[r'$<R>$',r'$<R^2>$']
Y1=[y1, y2]
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0])
    ax.plot(X, Y0[i],linestyle='-',label='Cavity: $0^{th}$',linewidth=3,c=tableau20[6])
    ax.plot(X, Y1[i],linestyle='-.',label='Cavity: $1^{st}$',linewidth=3,c=tableau20[6])
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.01,10.1)
    if i==0: ax.set_ylim(0.,1.5)
    if i==1: ax.set_ylim(0.,2)
    if i==0: ax.legend(fontsize=15,loc='upper right')
    i=i+1

fig.tight_layout()
fig_name='resource_compare.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Species

# %%
from scipy.stats import truncnorm
from scipy.stats import norm
gamma=1
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['mean_N'], data0['q_N']]
chi=-data0['phi_N']/(data0['nu']*data0['epsilon']**2)
Pre=np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)/(data0['epsilon']**2*data0['chi'])
a, b = (mu*data0['mean_R']-m)/(np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)), 100*np.ones(len(X))

momentum1s = [quad(integrmomentum1, -i, np.inf, args=(i,))[0] for i in a] 
momentum2s = [quad(integrmomentum2, -i, np.inf, args=(i,))[0] for i in a]
Y0=[Pre*momentum1s, Pre**2*momentum2s]

Labels=[ '$<N>$',r'$<N^2>$']
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
    ax.plot(X, Y0[i], linestyle='-',label='Cavity',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.05,10.1)
    if i==0:
        ax.legend(fontsize=15,loc='upper right')
        ax.set_ylim(-0.01,1.1)
    if i==1:ax.set_ylim(-0.01,6.1)
    i=i+1

fig.tight_layout()
fig_name='species_compare.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Consumer power
# #### Simulations

# %%
from scipy.stats import truncnorm
from scipy.stats import norm
gamma=1
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['power']/100]
Y0=[m*data0['mean_N']-sigm**2/data0['epsilon']**2*data0['phi_N']/data0['chi']]

i=0
Labels=['$<P>$']
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(5, 4))
ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
ax.plot(X, Y0[i], linestyle='-',label='Self-consistency of power',linewidth=3,c=tableau20[6],alpha=0.7)
ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
ax.set_ylabel(Labels[i],fontsize=16)
ax.set_xlim(0.05,15.1)
ax.legend(fontsize=15,loc='upper right')
ax.set_ylim(-0.01,1.1)


fig.tight_layout()
fig_name='Power_compare1.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# #### Cavity solutions

# %%
gamma=1
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.

file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['power']/100]
Y0=[m*data0['mean_N']-sigm**2/data0['epsilon']**2*data0['phi_N']/data0['chi']]

file_name='Data/Cavity_linear.csv'
data1=pd.read_csv(file_name)
data1=data1[data1['K']==k]
X1=data1['Sigc']
Y1=[m*data1['N']-sigm**2/data1['Sigc']**2*data1['phiN']/data1['Chi']]

file_name='Data/Cavity_linear_1st.csv'
data2=pd.read_csv(file_name)
data2=data2[data2['K']==k]
X2=data2['Sigc']
Y2=[m*data2['N']-sigm**2/data2['Sigc']**2*data2['phiN']/data2['Chi']]


i=0
Labels=['$<P>$']
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(5, 4))
ax.plot(X, Y[i],label='Simulations',linestyle='-',linewidth=3,c=tableau20[8],alpha=0.7)
ax.plot(X, Y0[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[8],alpha=0.7)
ax.plot(X1, Y1[i],label='Left 0th',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
ax.plot(X1, k-data1['R'],label='Right 0th',linestyle='-',linewidth=3,c=tableau20[0],alpha=0.7)
ax.plot(X2, Y2[i], linestyle='--',label='Left 1st',linewidth=3,c=tableau20[6],alpha=0.7)
ax.plot(X2, k-data2['R'],label='Right 1st',linestyle='-',linewidth=3,c=tableau20[6],alpha=0.7)
ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
ax.set_ylabel(Labels[i],fontsize=16)
ax.set_xlim(0.1,2.1)
ax.legend(fontsize=15,loc='upper right')
ax.set_ylim(-0.01,2)


fig.tight_layout()
fig_name='Power_compare2.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Growth Rates

# %% [markdown]
# #### Linear

# %%
from scipy.stats import truncnorm
from scipy.stats import norm
gamma=1.
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['mean_Growth'], data0['q_Growth']]
Pre=np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)
a, b = (-1000*np.ones(len(X)), (mu*data0['mean_R']-m)/(np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)))

momentum1s = [quad(integrmomentum1, -np.inf, -i, args=(i,))[0] for i in b] 
momentum2s = [quad(integrmomentum2, -np.inf, -i, args=(i,))[0] for i in b]
Y0=[Pre*momentum1s, Pre**2*momentum2s]
Labels=[ '$<G>$',r'$<G^2>$']
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
    ax.plot(X, Y0[i],linestyle='-',label='Cavity',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(-0.01,15.1)
    if i==0:
        ax.legend(fontsize=15,loc='upper right')
        #ax.set_ylim(-0.01,1.1)
    if i==1:ax.set_ylim(-0.01,140.1)
    i=i+1

fig.tight_layout()
fig_name='growth_compare_li.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# #### Quadratic

# %%
from scipy.stats import truncnorm
from scipy.stats import norm
gamma=1.
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_quadratic_CVXOPT_log_sigc_1.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['mean_Growth'], data0['q_Growth']]
Pre=np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)
a, b = (-1000*np.ones(len(X)), (mu*data0['mean_R']-m)/(np.sqrt(data0['q_R']*data0['epsilon']**2+sigm**2)))


momentum1s = [quad(integrmomentum1, -np.inf, -i, args=(i,))[0] for i in b] 
momentum2s = [quad(integrmomentum2, -np.inf, -i, args=(i,))[0] for i in b]
Y0=[Pre*momentum1s, Pre**2*momentum2s]

Labels=[ '$<G>$',r'$<G^2>$']
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
    ax.plot(X, Y0[i],linestyle='-',label='Cavity',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.set_xlabel(r'$\sigma_c$',fontsize=fontsize)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(-0.01,15.1)
    if i==0:
        ax.legend(fontsize=15,loc='upper right')
        #ax.set_ylim(-0.01,1.1)
    if i==1:ax.set_ylim(-0.01,140.1)
    i=i+1

fig.tight_layout()
fig_name='growth_compare_qu.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Suspecties

# %%
gamma=1
mu=1.
k=5.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['chi'], data0['nu']]
Y0=[k/(1+mu*data0['mean_N']/gamma)**2-data0['phi_N']*3*k/gamma/(1+mu*data0['mean_N']/gamma)**2, -data0['phi_N']*(1+mu*data0['mean_N']/gamma)**2/(data0['epsilon']**2*k)]
Chi=-gamma/(2*data0['nu']*data0['epsilon']**2)*(1-\
(gamma+mu*data0['mean_N'])/np.sqrt((gamma+mu*data0['mean_N'])**2-4*data0['nu']*gamma*k*data0['epsilon']**2)\
+3*(1+mu*data0['mean_N']/gamma)*(data0['epsilon']**2*data0['q_N'])/2/((1+mu*data0['mean_N'])**2/gamma-4*data0['nu']/gamma*k*data0['epsilon']**2)**(3/2))
Y1=[Chi,-data0['phi_N']/(data0['epsilon']**2*Chi)]
Labels=[ '$\chi$',r'$\nu$']
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
    if i==0:
        ax.plot(X, Y0[i],linestyle='-',label='Cavity 0th',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.plot(X, Y1[i],linestyle='-.',label='Cavity 1st',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.set_xlabel(r'$\sigma_c$',fontsize=16)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.01,10.1)
    if i==0:
        ax.legend(fontsize=15,loc='center right')
    i=i+1

fig.tight_layout()
fig_name='Suspecities_compare.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %%
gamma=1
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['chi'], data0['nu']]

file_name='Data/Cavity_linear.csv'
data2=pd.read_csv(file_name)
data2=data2[data2['K']==k]
X0=data2['Sigc']
Y0=[data2['Chi']]



file_name='Data/Cavity_linear_1st.csv'
data2=pd.read_csv(file_name)
data2=data2[data2['K']==k]
X1=data2['Sigc']
Y1=[data2['Chi'],data2['Nu']]
Labels=[ '$\chi$',r'$\nu$']
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
i=0
for ax in axes.flat:
    ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
    if i==0: 
        ax.plot(X0, Y0[i],linestyle='-',label='Cavity 0th',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.plot(X1, Y1[i],linestyle='-.',label='Cavity 1st',linewidth=3,c=tableau20[6],alpha=0.7)
    ax.set_xlabel(r'$\sigma_c$',fontsize=16)
    ax.set_ylabel(Labels[i],fontsize=16)
    ax.set_xlim(0.01,1.1)
    if i==0:
        ax.legend(fontsize=15,loc='center right')
    i=i+1

fig.tight_layout()
fig_name='Suspecities_compare.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ### Cavity Approximations: Dominator

# %%
gamma=1
mu=1.
k=1.
sigk=0.1
sigm=0.1
m=1.
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_sigc_2.csv'
data0=pd.read_csv(file_name)
data0=data0[data0['K']==k]
X=data0['epsilon']
Y=[data0['mean_Dominator'], data0['q_Dominator']]
Y0=[1+gamma*mu*data0['mean_N']+data0['mean_R']*data0['phi_N']/data0['chi']]
Y1=[1+gamma*mu*data0['mean_N']]
fig, ax= plt.subplots(nrows=1, ncols=1,figsize=(5, 4))
i=0
ax.plot(X, Y[i],label='Simulations',linestyle='--',linewidth=3,c=tableau20[0],alpha=0.7)
ax.plot(X, Y0[i], linestyle='-',label='With backreaction correction (cavity)',linewidth=3,c=tableau20[6],alpha=0.7)
ax.plot(X, Y1[i], linestyle='-',label='Without backreaction',linewidth=3,c=tableau20[8],alpha=0.7)
ax.set_xlabel(r'$\sigma_c$',fontsize=15)
ax.set_ylabel(r'$1+\sum_i N_iC_{i\alpha}$',fontsize=16)
ax.set_xlim(0.05,10.1)
ax.legend(fontsize=10,loc='upper right')


fig.tight_layout()
fig_name='dominator_compare.pdf'
fig.savefig(fig_name, dpi=300,bbox_inches='tight',transparent='True')

# %% [markdown]
# ## Species Packing Bounds
# ### Quadratic

# %%
file_name='Data/Community_gaussian_null_quadratic_CVXOPT_log_v0.csv'
data=pd.read_csv(file_name)
X=data['K']
Y=data['epsilon']
Z=data['Survive']/100
Points=np.zeros((len(X),2))
Points[:,0]=X
Points[:,1]=Y
fontsize=20
methods = ['linear','cubic']
grid_x, grid_y = np.meshgrid(np.arange(1, 20.1, 0.5), np.arange(0.1, 2.1, 0.1))
zi = griddata((X, Y), Z, (grid_x, grid_y), method='cubic')
fig, ax = plt.subplots()
v = np.linspace(0, 1.0, 10, endpoint=False)
cs = ax.contourf(grid_x, grid_y, zi,levels=v,cmap='jet')
cbar = fig.colorbar(cs,ticks=v)
#ax.set_xscale("log") 
#ax.set_yscale("log") 
ax.set_ylabel(r'$\sigma_c$',fontsize=fontsize)
ax.set_xlabel(r'$K$',rotation=0,fontsize=fontsize)
cbar.set_label(r'$\frac{S^*}{M}$', labelpad=-30, y=-0.02, rotation=0,fontsize=fontsize)
fig.tight_layout()
fig.savefig('Ksigc_qu.pdf',dpi=300)

# %% [markdown]
# ### Linear

# %%
file_name='Data/Community_gaussian_null_linear_CVXOPT_log_v0.csv'
data=pd.read_csv(file_name)
X=data['K']
Y=data['epsilon']
Z=data['Survive']/100
Points=np.zeros((len(X),2))
Points[:,0]=X
Points[:,1]=Y
fontsize=20
methods = ['linear','cubic']
grid_x, grid_y = np.meshgrid(np.arange(1, 20.1, 0.5), np.arange(0.1,2.1, 0.1))
zi = griddata((X, Y), Z, (grid_x, grid_y), method='cubic')
fig, ax = plt.subplots()
v = np.linspace(0, 1.0, 10, endpoint=False)
cs = ax.contourf(grid_x, grid_y, zi,levels=v,cmap='jet')
cbar = fig.colorbar(cs,ticks=v)
#ax.set_xscale("log") 
#ax.set_yscale("log") 
ax.set_ylabel(r'$\sigma_c$',fontsize=fontsize)
ax.set_xlabel(r'$K$',rotation=0,fontsize=fontsize)
cbar.set_label(r'$\frac{S^*}{M}$', labelpad=-30, y=-0.02, rotation=0,fontsize=fontsize)
fig.tight_layout()
fig.savefig('Ksigc_li.pdf',dpi=300)

# %% [markdown]
# ## Test suspecities calculations

# %%
S=3
M=2
N=1*np.ones(S)+np.random.randn(S)
C=np.random.randn(S,M)
C=np.random.randn(S,M)
R=1*np.ones(M)+np.random.randn(M)

# %% [markdown]
# ### From Inverse of Whole Matrix

# %%
#W1=np.tile(np.dot(N,C)+1, (M, 1))
B=np.diag(np.concatenate((np.ones(S), -R)))
W1=np.diag(np.dot(N,C)+1)
W2=(np.einsum('ij,j->ij', C, R)).T
A=np.concatenate((np.concatenate((C, W1)),np.concatenate((np.zeros([S,S]), W2))),axis=1)
Sup=np.linalg.inv(A).dot(B)
Chi_R=Sup[0:M,S:]
Nu_N=Sup[M:, 0:S]

# %% [markdown]
# ### From Inversie of Block Matrix

# %%
W3=(np.einsum('ij,j->ij', C, R/(np.dot(N,C)+1))).T
H=np.linalg.inv(W3.T.dot(C.T))

# %%
Chi1_R=-np.diag(R/(np.dot(N,C)+1))+W3.dot(H).dot(W3.T)
Nu1_N=-H
